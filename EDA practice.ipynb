# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\CHARMY R PATEL\\Downloads\\Titanic-Dataset.csv")
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv("C:\\Users\\CHARMY R PATEL\\Downloads\\Titanic-Dataset.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)

ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot(x='Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('survived vs sex')

sns.countplot(x='Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('sex:survived vs Dead')
plt.show()

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_5ae2a_row0_col0, #T_5ae2a_row1_col1, #T_5ae2a_row1_col2 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_5ae2a_row0_col1 {
#   background-color: #00ce98;
#   color: #000000;
# }
# #T_5ae2a_row0_col2 {
#   background-color: #00f485;
#   color: #000000;
# }
# #T_5ae2a_row1_col0 {
#   background-color: #00f684;
#   color: #000000;
# }
# #T_5ae2a_row2_col0 {
#   background-color: #0060cf;
#   color: #f1f1f1;
# }
# #T_5ae2a_row2_col1 {
#   background-color: #00df90;
#   color: #000000;
# }
# #T_5ae2a_row2_col2 {
#   background-color: #0090b7;
#   color: #f1f1f1;
# }
# #T_5ae2a_row3_col0, #T_5ae2a_row3_col1, #T_5ae2a_row3_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ae2a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_5ae2a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5ae2a_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#3B1733','#F089D9','#F7C8ED'],ax=ax[0])
ax[0].set_title('Number of passengers by pclass')
ax[0].set_ylabel('COUNT')

sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('pclass:survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_4fe7a_row0_col0, #T_4fe7a_row0_col1, #T_4fe7a_row0_col3, #T_4fe7a_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_4fe7a_row0_col2, #T_4fe7a_row1_col2 {
#   background-color: #0e8666;
#   color: #f1f1f1;
# }
# #T_4fe7a_row1_col0 {
#   background-color: #69b466;
#   color: #f1f1f1;
# }
# #T_4fe7a_row1_col1 {
#   background-color: #5cae66;
#   color: #f1f1f1;
# }
# #T_4fe7a_row1_col3 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_4fe7a_row2_col0 {
#   background-color: #58ac66;
#   color: #f1f1f1;
# }
# #T_4fe7a_row2_col1, #T_4fe7a_row2_col3 {
#   background-color: #7abc66;
#   color: #000000;
# }
# #T_4fe7a_row2_col2 {
#   background-color: #91c866;
#   color: #000000;
# }
# #T_4fe7a_row3_col0 {
#   background-color: #329866;
#   color: #f1f1f1;
# }
# #T_4fe7a_row3_col1 {
#   background-color: #0f8766;
#   color: #f1f1f1;
# }
# #T_4fe7a_row3_col3 {
#   background-color: #088466;
#   color: #f1f1f1;
# }
# ...

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',data=data,kind='bar')
plt.show()

# %%
print('Oldest passenger was of:',data['Age'].max(),'years')
print('Youngest passenger was of:',data['Age'].min(),'years')
print('Average passenger was of:',data['Age'].mean(),'years')
# Out:
# Oldest passenger was of: 80.0 years
# Youngest passenger was of: 0.42 years
# Average passenger was of: 29.69911764705882 years

# %%
pd.read_csv("C:\\Users\\CHARMY R PATEL\\Downloads\\Titanic-Dataset.csv")
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Age'].value_counts().plot.bar(color=['#3B1733','#F089D9','#F7C8ED'],ax=ax[0])
ax[0].set_title('Number of passengers by age')
ax[0].set_ylabel('Count')

sns.countplot(x='Age',hue='Survived',data=data.head(10),ax=ax[1])
ax[1].set_title('age:survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c7f97_row0_col0, #T_c7f97_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_c7f97_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_c7f97_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_c7f97_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_c7f97_row0_col4, #T_c7f97_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_c7f97_row1_col0, #T_c7f97_row3_col0, #T_c7f97_row3_col1, #T_c7f97_row3_col2, #T_c7f97_row3_col3, #T_c7f97_row3_col4, #T_c7f97_row4_col0, #T_c7f97_row4_col2, #T_c7f97_row4_col3, #T_c7f97_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c7f97_row1_col1, #T_c7f97_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_c7f97_row1_col3, #T_c7f97_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_c7f97_row2_col0, #T_c7f97_row5_col1 {
#   background-color: #e6f266;
# ...

# %%
sns.catplot(x='Embarked',y='Survived',data=data,kind='bar')
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot(x='Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')

sns.countplot(x='Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')

sns.countplot(x='Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')

sns.countplot(x='Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',col='Embarked',data=data,kind='bar')
plt.show()

# %%
data['Embarked'].fillna('S',inplace = True)
data.Embarked.isnull().any()
# Out:
# C:\Users\CHARMY R PATEL\AppData\Local\Temp\ipykernel_10740\2731514978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna('S',inplace = True)
# np.False_

# %%
data = pd.read_csv("C:\\Users\\CHARMY R PATEL\\Downloads\\Titanic-Dataset.csv")
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_1e217_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1e217_row1_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_1e217_row2_col0 {
#   background-color: #87c366;
#   color: #000000;
# }
# #T_1e217_row3_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_1e217_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1e217">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e217_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_band</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e217_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1e217_row0_col0" class="data row0 col0" >346</td>
#     </tr>
#     <tr>
# ...
